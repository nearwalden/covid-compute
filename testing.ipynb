# %%
import pandas as p

# %%
import importlib

# %%
import covid

# %%
import states

# %%
# %matplotlib inline

# %%
importlib.reload(covid)
# Out:
# <module 'covid' from '/Users/dd/gitcode/covid-compute/covid.py'>

# %%
path = covid.COVID_19_REPO_PATH + covid.COVID_19_CONFIRMED

# %%
cd = covid.CovidData("/Users/dd/gitcode/")

# %%
cd.plot_states(['MA'], 'confirmed')

# %%
cd.states['MA'].to_csv('/Users/dd/Desktop/ma.csv')
