# %%
import pandas as p

# %%
import numpy as np

# %%
import importlib

# %%
import covid

# %%
import states

# %%
# %matplotlib inline

# %%
importlib.reload(covid)
# Out:
# <module 'covid' from '/Users/dd/gitcode/covid-compute/covid.py'>

# %%
cd = covid.CovidData('/Users/dd/gitcode/')

# %%
a = states.analyze('/Users/dd/gitcode/')

# %%
a.to_csv('results/states-20200321.csv')

# %%
a
# Out:
#        confirmed  confirmed/1M  deaths  deaths/1M  pct_change_2day  \
# state
# AK            15     20.504549       0   0.000000         0.291667
# AL           131     26.717328       0   0.000000         0.321208
# AR           122     40.426466       0   0.000000         0.409610
# AZ           118     16.211648       1   0.137387         0.623077
# CA          1364     34.520963      24   0.607407         0.197612
# CO           390     67.723195       4   0.694597         0.192425
# CT           194     54.413572       4   1.121929              NaN
# DC            77    109.103945       1   1.416934         0.429754
# DE            45     46.212429       0   0.000000         0.225439
# FL           659     30.682935      13   0.605278         0.260318
# GA           507     47.751700      14   1.318587         0.335279
# HI            37     26.132306       0   0.000000         0.524038
# IA            68     21.552612       0   0.000000         0.266919
# ID            36     20.143838       0   0.000000         0.828063
# IL           753     59.423188       6   0.473492         0.336718
# IN           128     19.013048       4   0.594158         0.460853
# KS            57     19.565347       2   0.686503         0.294786
# KY            87     19.473225       3   0.671491         0.560667
# LA           585    125.839089      16   3.441753         0.229905
# MA           525     75.544971       1   0.143895         0.265166
# MD           193     31.923621       2   0.330815         0.343913
# ME            70     52.075119       0   0.000000         0.163462
# MI           788     78.903703       5   0.500658         0.540115
# MN           138     24.469682       1   0.177317         0.246067
# MO            74     12.057168       3   0.488804         0.552952
# MS           140     47.040656       1   0.336005         0.675000
# MT            21     19.648608       0   0.000000         0.381818
# NC           253     24.122614       0   0.000000         0.434652
# ND            28     36.742417       0   0.000000         0.264620
# NE            38     19.644253       0   0.000000         0.151445
# NH            55     40.449772       0   0.000000         0.125000
# NJ          1327    149.400092      16   1.801358         0.345236
# NM            43     20.507156       0   0.000000              NaN
# NV           161     52.270080       2   0.649318         0.306140
# NY         11710    601.946348      60   3.084268         0.479037
# OH           248     21.216347       3   0.256649         0.443654
# OK            53     13.394084       1   0.252719         0.097635
# OR           114     27.028712       5   1.185470              NaN
# PA           396     30.932693       2   0.156226         0.388902
# PR            21      6.575458       1   0.313117         1.150000
# RI            66     62.301708       0   0.000000         0.224747
# SC           171     33.212177       3   0.582670         0.456349
# SD            14     15.825307       1   1.130379              NaN
# TN           371     54.293949       1   0.146345         0.552631
# TX           581     20.037329       5   0.172438         0.495002
# UT           136     42.421017       0   0.000000         0.359295
# VA           156     18.276569       2   0.234315         0.255506
# VT            29     46.475178       2   3.205185              NaN
# WA          1793    235.459645      94  12.344231         0.142034
# WI           282     48.433353       4   0.686998         0.332103
# WV             8      4.464124       0   0.000000         1.321429
# WY            23     39.740203       0   0.000000         0.133041
# US         25399     77.092925     307   0.931829         0.367302
#
#        pct_change_2day_prev  pct_change_3day  pct_change_3day_prev
# state
# AK                 0.750000         0.361111              1.000000
# AL                 0.437570         0.446023              0.646994
# AR                 0.689394         0.566003              0.291667
# AZ                 0.508333         0.637607              0.281909
# CA                 0.171787         0.220955              0.212195
# CO                 0.327717         0.296761              0.123791
# CT                      NaN         0.779181              0.633333
# DC                 0.349707         0.383277              0.261364
# DE                 0.383224         0.343275              0.443452
# FL                 0.390865         0.282887              0.398359
# GA                 0.402612         0.370923              0.263949
# HI                 0.271429         0.396978              0.331746
# IA                 0.389055         0.350360              0.179549
# ID                 0.173611         0.626116              0.241667
# IL                 0.805575         0.759458              0.222859
# IN                 0.419231         0.486722              0.250000
# KS                 0.444444         0.492820              0.337121
# KY                 0.204416         0.497235              0.108852
# LA                 0.418258         0.328367              0.415635
# MA                 0.252294         0.344973              0.102606
# MD                 0.337745         0.315550              0.387110
# ME                 0.275298         0.188339              0.537173
# MI                 1.650510         1.368109              0.369800
# MN                 0.219589         0.215993              0.312434
# MO                 0.679293         0.609375              0.556566
# MS                 0.544818         0.606863              0.511477
# MT                 0.111111         0.254545              0.169312
# NC                 0.425446         0.542149              0.309825
# ND                 1.500000         0.843080              1.000000
# NE                 0.175595         0.170407              0.122782
# NH                 0.346154         0.314103              0.279035
# NJ                 0.889513         0.823166              0.438776
# NM                      NaN         0.375155              0.176471
# NV                 0.354708         0.446518              0.367196
# NY                 0.806393         0.702791              0.515914
# OH                 0.333652         0.423676              0.324978
# OK                 0.657895         0.503686              0.442857
# OR                      NaN         0.294786              0.361305
# PA                 0.356203         0.377689              0.326118
# PR                 0.000000         0.766667              0.000000
# RI                 0.384058         0.260943              0.193340
# SC                 0.361702         0.545368              0.200938
# SD                      NaN         0.136364              0.050000
# TN                 0.508467         0.684876              0.274659
# TX                 0.537809         0.497631              0.349133
# UT                 0.284314         0.429072              0.233516
# VA                 0.217484         0.265575              0.201830
# VT                      NaN         0.270202              0.250000
# WA                 0.149691         0.213690              0.179518
# WI                 0.503019         0.464156              0.426148
# WV                 0.500000         1.214286                   inf
# WY                 0.281818         0.155361              1.010101
# US                 0.488867         0.499365              0.312185

# %%
cd.plot_state_2day (['US'])

# %%
cd.confirmed_countries.to_csv ('~/Desktop/confirmed_countries.csv')

# %%
df.iloc[-6:-3]
# Out:
#    A  B
# 2  a  3
# 3  b  4
# 4  b  5

# %%
bins = p.IntervalIndex.from_tuples([(0, 0.24), (0.24, 0.35), (0.35, 0.7), (0.7, 1.4), (1.4, 20)])

# %%
cd.confirmed_us['US_no_NY'] = cd.confirmed_us['US'] - cd.confirmed_us['NY']

# %%
p.cut(a['pct_change_2day'], bins).value_counts()
# Out:
# (0.35, 0.7]     19
# (0.24, 0.35]    15
# (0.0, 0.24]     11
# (0.7, 1.4]       3
# (1.4, 20.0]      0
# Name: pct_change_2day, dtype: int64

# %%
cd.confirmed_us['US_no_NY'].pct_change()
# Out:
# 1/22/20         NaN
# 1/23/20    0.000000
# 1/24/20    1.000000
# 1/25/20    0.000000
# 1/26/20    1.500000
# 1/27/20    0.000000
# 1/28/20    0.000000
# 1/29/20    0.000000
# 1/30/20    0.000000
# 1/31/20    0.400000
# 2/1/20     0.142857
# 2/2/20     0.000000
# 2/3/20     0.375000
# 2/4/20     0.000000
# 2/5/20     0.000000
# 2/6/20     0.000000
# 2/7/20     0.000000
# 2/8/20     0.000000
# 2/9/20     0.000000
# 2/10/20    0.000000
# 2/11/20    0.090909
# 2/12/20    0.000000
# 2/13/20    0.083333
# 2/14/20    0.000000
# 2/15/20    0.000000
# 2/16/20    0.000000
# 2/17/20    0.000000
# 2/18/20    0.000000
# 2/19/20    0.000000
# 2/20/20    0.000000
# 2/21/20    0.153846
# 2/22/20    0.000000
# 2/23/20    0.000000
# 2/24/20    0.000000
# 2/25/20    0.000000
# 2/26/20    0.000000
# 2/27/20    0.066667
# 2/28/20    0.000000
# 2/29/20    0.500000
# 3/1/20     0.250000
# 3/2/20     0.733333
# 3/3/20     0.365385
# 3/4/20     0.309859
# 3/5/20     0.602151
# 3/6/20     0.248322
# 3/7/20     0.397849
# 3/8/20     0.323077
# 3/9/20     0.084302
# 3/10/20    0.927614
# 3/11/20    0.382476
# 3/12/20    0.275654
# 3/13/20    0.333596
# 3/14/20    0.261975
# 3/15/20    0.263355
# 3/16/20    0.333086
# 3/17/20    0.291597
# 3/18/20    0.123007
# 3/19/20    0.578362
# 3/20/20    0.300559
# 3/21/20    0.279226
# Name: US_no_NY, dtype: float64
