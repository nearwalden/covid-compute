# %%
import pandas as p

# %%
import importlib

# %%
import covid

# %%
import states

# %%
# %matplotlib inline

# %%
importlib.reload(covid)
# Out:
# <module 'covid' from '/Users/dd/gitcode/covid-compute/covid.py'>

# %%
path = covid.COVID_19_REPO_PATH + covid.COVID_19_CONFIRMED

# %%
cd = covid.CovidData()

# %%
cd.plot_countries(['US', 'United Kingdom'], 'deaths')
