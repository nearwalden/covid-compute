# %%
# Testing new file format

# %%
import pandas as p

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 4, 27)

# %%
d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
b = p.read_csv('~/gitcode/covid-compute/data/state_confirmed.csv')

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Middlesex, MA')

# %%
cd.plot_state ('FL')

# %%
a = states.analyze()

# %%
a
# Out:
#          conf       conf/1M  conf_days_peak  conf_pct_chg  conf_pct_chg_prev  \
# state
# WA      13686   1797.267539              25      0.013685           0.021959
# IL      45883   3620.868698              17      0.047994           0.063549
# AZ       6725    923.926566              22      0.034342           0.043582
# CA      44966   1138.027592               7      0.030206           0.034921
# MA      56462   8124.609774               3      0.028772           0.077072
# WI       6081   1044.408576               2      0.034075           0.060987
# TX      25321    873.261964              18      0.023940           0.032705
# OR       2354    558.119200              22      0.022175           0.029209
# RI       7708   7276.084357              10      0.039823           0.067500
# FL      32138   1496.340140              25      0.020845           0.019936
# NH       1938   1425.302877              12      0.038492           0.037354
# NY     291996  15009.899730              12      0.017318           0.034857
# GA      24302   2288.879326              10      0.023056           0.030143
# NC       9428    898.924913               2      0.037011           0.058881
# NJ     111188  12518.083941              24      0.026637           0.027008
# NV       4700   1525.896740              10      0.017889           0.038606
# TN       9918   1451.448478               4      0.038992           0.054355
# CO      13879   2410.077489               3      0.034531           0.072406
# IN      15961   2370.837906               0      0.052894           0.050859
# KY       4156    930.238180              17      0.030402           0.061110
# MD      19487   3223.293327              19      0.047317           0.062533
# MN       3811    675.753312              10      0.051647           0.082272
# NE       3358   1735.931613               4      0.111314           0.111259
# PA      43558   3402.440043               4      0.028827           0.035580
# CT      25997   7291.699097               5      0.028358           0.031610
# HI        607    428.711070              24      0.001652           0.007522
# OK       3281    829.169585              23      0.013541           0.028931
# SC       5613   1090.175139              18      0.033778           0.033606
# UT       4236   1321.289923              17      0.035867           0.045479
# DC       3892   5514.708487              19      0.025833           0.049078
# KS       3473   1192.113174               4      0.052553           0.073474
# MO       7305   1190.237995              17      0.026330           0.032500
# VA      13538   1586.078128               2      0.046318           0.060389
# VT        855   1370.216462              23      0.007095           0.010886
# IA       5868   1859.863648               2      0.073499           0.139165
# LA      27068   5822.585385              25      0.010432           0.014905
# AK        345    471.604618              30      0.008828           0.002967
# AR       3069   1016.957577               4      0.026788           0.058564
# DE       4162   4274.136238               1      0.079903           0.039719
# ID       1897   1061.468363              25      0.007195           0.029078
# ME       1023    761.040669              25      0.029848           0.014941
# MI      38210   3826.028549              24      0.015212           0.024962
# MS       6094   2047.612536               8      0.032356           0.053397
# MT        449    420.105953              25      0.004487           0.003389
# ND        942   1236.119896               9      0.083103           0.064268
# NM       2825   1347.272477               5      0.030564           0.057413
# OH      16325   1396.600252               8      0.023401           0.029941
# SD       2244   2536.570588              12      0.022371           0.047698
# WV       1063    593.170449               8      0.026069           0.014781
# WY        520    898.474149               6      0.029130           0.041103
# AL       6539   1333.622941               1      0.041963           0.016632
# PR       1389    434.919563               4      0.031048          -0.037288
# VI         57    543.302133              27      0.027441           0.000000
# GU        141    850.842998              22      0.000000           0.018224
# AS          0      0.000000              95           NaN                NaN
# MP         14    253.650759              26      0.000000           0.000000
# US     988045   2998.987335               3      0.026333           0.038936
#
#        deaths    deaths/1M  deaths_days_peak  deaths_pct_chg  \
# state
# WA        764   100.329709                 4        0.018154
# IL       1983   156.488953                19        0.028400
# AZ        275    37.781384                 5        0.003663
# CA       1779    45.024042                 5        0.026309
# MA       3003   432.117232                 8        0.048890
# WI        281    48.261603                22        0.027822
# TX        666    22.968780                 4        0.021709
# OR         92    21.812645                18        0.028736
# RI        233   219.943910                10        0.041068
# FL       1088    50.657106                 4        0.015525
# NH         60    44.127024                18        0.066038
# NY      22668  1165.236534                11        0.014865
# GA        995    93.713889                20        0.048084
# NC        340    32.417742                10        0.055839
# NJ       6044   680.462814                 5        0.010955
# NV        206    66.879729                20        0.002439
# TN        184    26.927457                13        0.019587
# CO        706   122.596348                 3        0.016005
# IN        844   125.367282                 6        0.036241
# KY        213    47.675826                20        0.019336
# MD        945   156.309960                 7        0.039231
# MN        286    50.712529                 1        0.083112
# NE         56    28.949425                 4        0.060000
# PA       1886   147.320858                 6        0.025687
# CT       2012   564.330445                 7        0.038687
# HI         16    11.300457                24        0.109890
# OK        197    49.785556                 6        0.007706
# SC        177    34.377516                18        0.032717
# UT         41    12.788689                21        0.000000
# DC        185   262.132855                13        0.059057
# KS        126    43.249715                16        0.024828
# MO        343    55.886603                 0        0.109566
# VA        460    53.892446                18        0.025979
# VT         47    75.321841                11        0.010870
# IA        127    40.252673                 3        0.064921
# LA       1740   374.290622                13        0.009625
# AK          9    12.302729                23        0.000000
# AR         51    16.899588                16        0.031250
# DE        125   128.367859                 2        0.056548
# ID         56    31.334859                17        0.000000
# ME         51    37.940444                 4        0.041915
# MI       3407   341.148371                 5        0.039233
# MS        229    76.945072                 6        0.017980
# MT         14    13.099072                28        0.000000
# ND         19    24.932355                 6        0.090074
# NM         99    47.214151                 5        0.032258
# OH        753    64.418989                 5        0.029125
# SD         11    12.434170                21        0.050000
# WV         34    18.972526                 7        0.031250
# WY          7    12.094844                 5        0.000000
# AL        228    46.500387                 6        0.044471
# PR         84    26.301831                18        0.006024
# VI          4    38.126465                22        0.166667
# GU          5    30.171738                36        0.000000
# AS          0     0.000000                95             NaN
# MP          2    36.235823                26        0.000000
# US      56256   170.752376                11        0.023029
#
#        deaths_pct_chg_prev
# state
# WA                0.018123
# IL                0.053978
# AZ                0.047294
# CA                0.049677
# MA                0.075563
# WI                0.015393
# TX                0.027774
# OR                0.023886
# RI                0.066570
# FL                0.034191
# NH                0.019608
# NY                0.024407
# GA                0.014665
# NC                0.041839
# NJ                0.044006
# NV                0.025433
# TN                0.017821
# CO                0.117926
# IN                0.055152
# KY                0.036060
# MD                0.081668
# MN                0.104536
# NE                0.031915
# PA                0.019836
# CT                0.066779
# HI                0.041667
# OK                0.041097
# SC                0.051996
# UT                0.082784
# DC                0.089575
# KS                0.030598
# MO                0.056227
# VA                0.082569
# VT                0.034355
# IA                0.080656
# LA                0.033231
# AK                0.000000
# AR                0.032861
# DE                0.103478
# ID                0.018519
# ME                0.034091
# MI                0.029484
# MS                0.048609
# MT                0.000000
# ND                0.033333
# NM                0.092033
# OH                0.041132
# SD                0.055556
# WV                0.016129
# WY                0.000000
# AL                0.017327
# PR                0.096932
# VI                0.000000
# GU                0.000000
# AS                     NaN
# MP                0.000000
# US                0.037353

# %%
states.pct_change_bins_conf(d)
# Out:
# (0.0, 0.06]     49
# (0.06, 0.12]     5
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     43
# (0.06, 0.12]     9
# (0.12, 0.24]     1
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    12
# (30, 40]         9
# (50, 75]         8
# (20, 30]         8
# (75, 100]        5
# (10, 20]         5
# (0, 10]          4
# (40, 50]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 1]       15
# (1, 2]       12
# (10, 500]     6
# (4, 6]        6
# (2, 3]        5
# (8, 10]       2
# (3, 4]        2
# (6, 8]        0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 3, 22)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 3, 15)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.06, 0.12]    26
# (0.0, 0.06]     14
# (0.12, 0.24]    11
# (0.24, 0.35]     1
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# Name: pct_change_2day, dtype: int64

# %%
d45 = datetime.date(2020, 4, 5)

# %%
states.pct_change_bins_deaths(d45)
# Out:
# (0.12, 0.24]    26
# (0.06, 0.12]    12
# (0.24, 0.35]     7
# (0.0, 0.06]      4
# (0.35, 0.7]      1
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# Name: pct_change_2day, dtype: int64

# %%
cd.plot_state_pct_change(['CO'])

# %%
d = states.deaths_1m (d)

# %%
d
# Out:
#     deaths_1m state
# 0    1.444538    WA
# 1    8.443932    IL
# 2    2.335576    AZ
# 3    2.227159    CA
# 4   28.203456    MA
# 5    0.858747    WI
# 6    0.689753    TX
# 7    0.711282    OR
# 8   12.271549    RI
# 9    2.747031    FL
# 10   1.470901    NH
# 11  22.515158    NY
# 12   1.695327    GA
# 13   1.239502    NC
# 14  28.934306    NJ
# 15   0.649318    NV
# 16  -0.292690    TN
# 17  21.185205    CO
# 18   5.198880    IN
# 19   2.014472    KY
# 20   8.270368    MD
# 21   3.723647    MN
# 22   1.550862    NE
# 23   1.796596    PA
# 24  35.901738    CT
# 25   0.706279    HI
# 26   2.274467    OK
# 27   1.359563    SC
# 28   1.247677    UT
# 29  19.837081    DC
# 30   1.716259    KS
# 31   3.258694    MO
# 32   4.451985    VA
# 33   1.602592    VT
# 34   3.486452    IA
# 35  13.121683    LA
# 36   0.000000    AK
# 37   0.662729    AR
# 38   8.215543    DE
# 39   0.000000    ID
# 40   2.231791    ME
# 41  10.814213    MI
# 42   2.688037    MS
# 43   0.000000    MT
# 44   0.000000    ND
# 45   2.861464    NM
# 46   2.908693    OH
# 47   1.130379    SD
# 48   0.558015    WV
# 49   0.000000    WY
# 50   1.427643    AL
# 51   2.504936    PR
# 52   0.000000    VI
# 53   0.000000    GU
# 54   0.000000    AS
# 55   0.000000    MP
# 56   6.055372    US
