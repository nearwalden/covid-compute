# %%
# Testing new file format

# %%
import pandas as p

# %%
import inspect

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 7, 3)

# %% [markdown]
# d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Boulder, CO')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
cd.plot_state ('MA')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
cd.plot_state ('US')

# %%
a = states.analyze()

# %%
a
# Out:
#           conf       conf/1M  day conf  day conf/1M  deaths    deaths/1M  \
# state
# WA       34778   4567.102913     627.0    82.338649    1352   177.546815
# IL      145750  11501.898583    1737.0   137.075800    7005   552.801369
# AZ       91872  12622.004675    4427.0   608.211585    1798   247.021556
# CA      250514   6340.164662    3964.0   100.323386    6315   159.823961
# MA      109628  15774.941028     290.0    41.729603    8149  1172.601839
# WI       30317   5206.928924     579.0    99.442948     796   136.712584
# TX      185591   6400.598761    6454.0   222.583339    2592    89.392007
# OR        9636   2284.637473     342.0    81.086137     209    49.552639
# RI       16991  16038.914025      50.0    47.198264     960   906.206666
# FL      178594   8315.308079    9488.0   441.759763    3684   171.526451
# NH        5857   4307.532998      35.0    25.740764     376   276.529351
# NY      395872  20349.590494     918.0    47.189304   32137  1651.985464
# GA       90493   8523.066285    2784.0   262.210519    2857   269.086011
# NC       70262   6699.221707    2046.0   195.078529    1419   135.296399
# NJ      172742  19448.131598     386.0    43.457751   15164  1707.236616
# NV       20718   6726.282695     985.0   319.788998     528   171.419889
# TN       48712   7128.751587    1822.0   266.640364     633    92.636306
# CO       33595   5833.745461     260.0    45.148797    1701   295.377319
# IN       46915   6968.727547     528.0    78.428821    2681   398.234223
# KY       16376   3665.442838     297.0    66.477560     585   130.940649
# MD       68961  11406.657316     538.0    88.989163    3223   533.107938
# MN       37624   6671.357280     414.0    73.409045    1503   266.506751
# NE       19660  10163.316115     208.0   107.526437     284   146.814943
# PA       93392   7295.116407     780.0    60.928032    6746   526.949367
# CT       46717  13103.292947      71.0    19.914245    4335  1215.890895
# HI         975    688.621570      29.0    20.482077      19    13.419292
# OK       15069   3808.215931     538.0   135.962584     398   100.581986
# SC       41532   8066.480290    1831.0   355.622783     793   154.019042
# UT       23866   7444.264710     596.0   185.903870     181    56.457383
# DC       10435  14785.709934      45.0    63.762046     555   786.398564
# KS       15659   5374.978461     657.0   225.516371     282    96.796981
# MO       23160   3773.567690     524.0    85.377784    1047   170.592633
# VA       64393   7544.122390     658.0    77.089630    1845   216.155573
# VT        1236   1980.804149       9.0    14.423331      56    89.745172
# IA       30463   9655.253291     204.0    64.657836     721   228.521079
# LA       63289  13614.068509    1728.0   371.709308    3278   705.129115
# AK        1060   1448.988101      46.0    62.880616      15    20.504549
# AR       22622   7496.127178     547.0   181.256368     281    93.113418
# DE       11923  12244.239877     192.0   197.173032     512   525.794751
# ID        6994   3913.500121     401.0   224.379975      93    52.038249
# ME        3373   2509.276811      45.0    33.476862     105    78.112679
# MI       72175   7226.998444     497.0    49.765407    6215   622.317912
# MS       29684   9973.962997     914.0   307.108280    1103   370.613165
# MT        1128   1055.410946      45.0    42.104160      23    21.519904
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# (0.06, 0.12]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     46
# (0.06, 0.12]     4
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    13
# (50, 75]        10
# (75, 100]        9
# (40, 50]         6
# (0, 10]          5
# (20, 30]         4
# (10, 20]         4
# (30, 40]         1
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    14
# (50, 75]        10
# (75, 100]        6
# (30, 40]         6
# (40, 50]         4
# (10, 20]         4
# (0, 10]          4
# (20, 30]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (1, 2]       9
# (6, 8]       8
# (4, 6]       8
# (0, 1]       8
# (2, 3]       7
# (10, 500]    4
# (3, 4]       2
# (8, 10]      0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 4, 27)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 4, 18)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
m = states.deaths_1m_multi(d, 6)

# %%
m.loc[:, states.INTEREST].to_csv('~/Desktop/states.csv')

# %%
m['CA']
# Out:
# 05-29-2020    2.176542
# 06-05-2020    1.889711
# 06-12-2020    1.965636
# 06-19-2020    1.906583
# 06-26-2020    2.041562
# 07-03-2020    1.965636
# Name: CA, dtype: float64

# %%
m['deaths_1m'].mean()
# Out:
# 4.508771929824562

# %%
c = counties.deaths_1m(d)

# %%
c['deaths_1m'].value_counts().sort_index()
# Out:
# 0.0     20
# 1.0     21
# 2.0     15
# 3.0      4
# 4.0      3
# 5.0      3
# 6.0      1
# 10.0     3
# 11.0     1
# 12.0     2
# 13.0     1
# 14.0     3
# 16.0     2
# 17.0     1
# 18.0     1
# 19.0     3
# 20.0     1
# 21.0     2
# 22.0     1
# 23.0     1
# 24.0     1
# 26.0     3
# 27.0     1
# 34.0     1
# 40.0     1
# Name: deaths_1m, dtype: int64

# %%
a cd.counties_in_state('MA')

# %%
importlib.reload(counties)
# Out:
# <module 'counties' from '/Users/dd/gitcode/covid-compute/counties.py'>
