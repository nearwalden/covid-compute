# %%
# Testing new file format

# %%
import pandas as p

# %%
import inspect

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 5, 23)

# %%
d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Los Angeles, CA')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
cd.plot_state ('CO')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
cd.plot_state ('MA')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
a = states.analyze()

# %%
a
# Out:
#           conf       conf/1M  day conf  day conf/1M  deaths    deaths/1M  \
# state
# WA       19265   2529.910795       0.0     0.000000    1050   137.887689
# IL      107796   8506.748951    2352.0   185.608682    4790   378.004077
# AZ       16053   2205.471102     429.0    58.938959     801   110.046867
# CA       92539   2342.034767    2287.0    57.880823    3738    94.603637
# MA       91662  13189.720186     773.0   111.230976    6304   907.115228
# WI       14877   2555.116984     481.0    82.611499     507    87.076985
# TX       54776   1889.095903    1237.0    42.661232    1478    50.972757
# OR        3888    921.821346      24.0     5.690255     147    34.852813
# RI       13952  13170.203547     216.0   203.896500     597   563.547270
# FL       50127   2333.905104     676.0    31.474452    2233   103.968123
# NH        4089   3007.256689      75.0    55.158780     208   152.973683
# NY      359926  18501.805402    1772.0    91.088721   29031  1492.323179
# GA       42242   3978.554872     760.0    71.580458    1822   171.604729
# NC       22864   2179.997796     754.0    71.891110     778    74.179421
# NJ      153140  17241.243432     561.0    63.160099   11082  1247.665272
# NV        7526   2443.382738       1.0     0.324659     387   125.642987
# TN       19785   2895.433367     391.0    57.220846     329    48.147464
# CO       23964   4161.329847     477.0    82.830677    1327   230.432512
# IN       30901   4590.017051     492.0    73.081402    1964   291.731448
# KY        8571   1918.448373     145.0    32.455374     391    87.517596
# MD       45495   7525.208082    1071.0   177.151288    2243   371.008720
# MN       19845   3518.846620     840.0   148.945889     861   152.669536
# NE       11963   6184.320991     301.0   155.603161     147    75.992242
# PA       71009   5546.716217     798.0    62.334064    5112   399.312951
# CT       40022  11225.463756     382.0   107.144250    3675  1030.772558
# HI         643    454.137097       1.0     0.706279      17    12.006735
# OK        5960   1506.202598     111.0    28.051760     311    78.595471
# SC        9895   1921.839123     257.0    49.915377     425    82.544884
# UT        8260   2576.452967     203.0    63.319607      97    30.256167
# DC        7966  11287.299026      73.0   103.436207     427   605.030967
# KS        8946   3070.729760      37.0    12.700313     205    70.366600
# MO       11966   1949.676640     130.0    21.181511     682   111.121467
# VA       35749   4188.263186     799.0    93.608836    1159   135.785533
# VT         954   1528.873105       2.0     3.205185      54    86.539987
# IA       16898   5355.824118     406.0   128.681773     446   141.359780
# LA       36925   7942.920250       0.0     0.000000    2668   573.912288
# AK         407    556.356752       4.0     5.467880      10    13.669699
# AR        5775   1913.629849     163.0    54.012410     115    38.106915
# DE        8529   8758.795766       0.0     0.000000     322   330.675605
# ID        2595   1452.035003       0.0     0.000000      79    44.204534
# ME        2013   1497.531639      65.0    48.355468      77    57.282631
# MI       54365   5443.654595     452.0    45.259485    5223   522.987362
# MS       13005   4369.740897     380.0   127.681779     616   206.978884
# MT         479    448.175393       0.0     0.000000      16    14.970368
# ND        2365   3103.422031      48.0    62.987001      52    68.235918
# NM        6625   3159.532799       0.0     0.000000     302   144.027005
# OH       31408   2686.947669     614.0    52.527568    1956   167.335381
# SD        4464   5046.012079     108.0   122.080937      50    56.518953
# WV        1705    951.416383       0.0     0.000000      72    40.177114
# WY         813   1404.729775      10.0    17.278349      12    20.734019
# AL       14117   2879.148961     447.0    91.165232     549   111.968037
# PR        3100    970.662812      70.0    21.918193     127    39.765864
# VI          69    657.681530       0.0     0.000000       6    57.189698
# GU         165    995.667338       0.0     0.000000       5    30.171738
# AS           0      0.000000       0.0     0.000000       0     0.000000
# MP          22    398.594050       0.0     0.000000       2    36.235823
# US     1622460   4924.610713   21675.0    65.789565   97084   294.676545
#
#        day deaths  day deaths/1M  conf_pct_chg  deaths_pct_chg
# state
# WA            0.0       0.000000      0.007719        0.002874
# IL           75.0       5.918644      0.024722        0.019675
# AZ           26.0       3.572058      0.023818        0.023973
# CA           72.0       1.822221      0.024441        0.021402
# MA           76.0      10.936034      0.010729        0.012608
# WI           11.0       1.889244      0.035996        0.020329
# TX            8.0       0.275901      0.017934        0.006146
# OR            0.0       0.000000      0.008261        0.006897
# RI           18.0      16.991375      0.014128        0.036227
# FL           43.0       2.002073      0.020653        0.020545
# NH            4.0       2.941802      0.018699        0.022367
# NY          178.0       9.149996      0.005325        0.004998
# GA           14.0       1.318587      0.020899        0.013167
# NC            3.0       0.286039      0.045122        0.034216
# NJ           97.0      10.920730      0.005961        0.010823
# NV            1.0       0.324659      0.009258        0.005212
# TN           14.0       2.048828      0.026327        0.025417
# CO            3.0       0.520948      0.015023        0.006476
# IN           23.0       3.416407      0.019207        0.013243
# KY            0.0       0.000000      0.015733        0.006477
# MD           36.0       5.954665      0.024528        0.019272
# MN           10.0       1.773165      0.037113        0.026047
# NE            0.0       0.000000      0.023994        0.032609
# PA          102.0       7.967512      0.015188        0.024659
# CT           38.0      10.658328      0.007957        0.012760
# HI            0.0       0.000000     -0.000754        0.000000
# OK            4.0       1.010874      0.028253        0.011449
# SC            6.0       1.165340      0.024924        0.010766
# UT            4.0       1.247677      0.022256        0.026940
# DC            9.0      12.752409      0.022434        0.018047
# KS            0.0       0.000000      0.023399        0.002451
# MO            5.0       0.814674      0.013271        0.010429
# VA           23.0       2.694622      0.030581        0.026487
# VT            0.0       0.000000      0.004231        0.000000
# IA           22.0       6.972904      0.027562        0.043017
# LA            0.0       0.000000      0.022586        0.007417
# AK            0.0       0.000000      0.002494        0.000000
# AR            2.0       0.662729      0.059580        0.022486
# DE            0.0       0.000000      0.020242        0.007886
# ID            0.0       0.000000      0.017757        0.012987
# ME            2.0       1.487861      0.034856        0.027032
# MI           65.0       6.508554      0.008491        0.009128
# MS           21.0       7.056098      0.027141        0.030578
# MT            0.0       0.000000      0.001046        0.000000
# ND            0.0       0.000000      0.051721        0.009804
# NM            0.0       0.000000      0.024089        0.013605
# OH           84.0       7.186182      0.022809        0.031962
# SD            0.0       0.000000      0.021427        0.020833
# WV            0.0       0.000000      0.043450        0.014286
# WY            0.0       0.000000      0.010143        0.000000
# AL            8.0       1.631593      0.023415        0.018736
# PR            1.0       0.313117      0.028282        0.003968
# VI            0.0       0.000000      0.000000        0.000000
# GU            0.0       0.000000      0.035714        0.000000
# AS            0.0       0.000000           NaN             NaN
# MP            0.0       0.000000      0.023810        0.000000
# US         1108.0       3.363084      0.015693        0.012515

# %%
states.pct_change_bins_conf(d)
# Out:
# (0.0, 0.06]     55
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# (0.06, 0.12]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     46
# (0.06, 0.12]     4
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    13
# (50, 75]        10
# (75, 100]        9
# (40, 50]         6
# (0, 10]          5
# (20, 30]         4
# (10, 20]         4
# (30, 40]         1
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    14
# (50, 75]        10
# (75, 100]        6
# (30, 40]         6
# (40, 50]         4
# (10, 20]         4
# (0, 10]          4
# (20, 30]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (1, 2]       9
# (6, 8]       8
# (4, 6]       8
# (0, 1]       8
# (2, 3]       7
# (10, 500]    4
# (3, 4]       2
# (8, 10]      0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 4, 27)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 4, 18)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
m = states.deaths_1m_multi(d, 6)

# %%
m.loc[:, states.INTEREST].to_csv('~/Desktop/states.csv')

# %%
m['MI']
# Out:
# 04-18-2020    12.916977
# 04-25-2020    11.415003
# 05-02-2020    11.715398
# 05-09-2020     9.145353
# 05-16-2020     5.573993
# 05-23-2020     5.440484
# Name: MI, dtype: float64

# %%
m['deaths_1m'].mean()
# Out:
# 4.508771929824562

# %%
c = counties.deaths_1m(d)

# %%
c['deaths_1m'].value_counts().sort_index()
# Out:
# 0.0     20
# 1.0     21
# 2.0     15
# 3.0      4
# 4.0      3
# 5.0      3
# 6.0      1
# 10.0     3
# 11.0     1
# 12.0     2
# 13.0     1
# 14.0     3
# 16.0     2
# 17.0     1
# 18.0     1
# 19.0     3
# 20.0     1
# 21.0     2
# 22.0     1
# 23.0     1
# 24.0     1
# 26.0     3
# 27.0     1
# 34.0     1
# 40.0     1
# Name: deaths_1m, dtype: int64

# %%
a cd.counties_in_state('MA')

# %%
importlib.reload(counties)
# Out:
# <module 'counties' from '/Users/dd/gitcode/covid-compute/counties.py'>
