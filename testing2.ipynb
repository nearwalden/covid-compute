# %%
# Testing new file format

# %%
import pandas as p

# %%
import inspect

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 6, 2)

# %% [markdown]
# d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Los Angeles, CA')

# %%
cd.plot_state ('US')

# %%
cd.plot_state ('WI')

# %%
a = states.analyze()

# %%
a
# Out:
#           conf       conf/1M  conf_pct_chg  day conf  day conf/1M  day deaths  \
# state
# WA       22157   2909.692887      0.014603     180.0    23.637890         6.0
# IL      122848   9694.581387      0.009696    1614.0   127.369223       113.0
# AZ       21264   2921.393976      0.022444    1135.0   155.934075        25.0
# CA      117215   2966.550376      0.021779    2482.0    62.816005        88.0
# MA      101163  14556.868311      0.023248     358.0    51.514475        50.0
# WI       18917   3248.984875      0.008549     374.0    64.234305        12.0
# TX       67310   2321.364197      0.023049    1717.0    59.215307        33.0
# OR        4335   1027.802350      0.013882      33.0     7.824101         3.0
# RI       15112  14265.203269      0.005788     121.0   114.219799        12.0
# FL       57447   2674.723133      0.012605     617.0    28.727421        70.0
# NH        4749   3492.653954      0.021353      64.0    47.068826        11.0
# NY      373040  19175.923627      0.002770    1329.0    68.316541        51.0
# GA       48207   4540.367281      0.016813     305.0    28.726368         8.0
# NC       30023   2862.581955      0.031845     431.0    41.094255        13.0
# NJ      161545  18187.519069      0.004096     627.0    70.590699        48.0
# NV        8858   2875.828367      0.010805     156.0    50.646785         0.0
# TN       24342   3562.326965      0.000000    1776.0   259.908499        17.0
# CO       26774   4649.284148      0.009141     211.0    36.639985        16.0
# IN       35237   5234.084037      0.009008     407.0    60.455550        54.0
# KY       10185   2279.710265      0.017622     139.0    31.112393         3.0
# MD       54175   8960.944013      0.012535     848.0   140.265446        45.0
# MN       25508   4522.990153      0.020845     300.0    53.194960        22.0
# NE       14616   7555.800017      0.015700     271.0   140.094541         0.0
# PA       77225   6032.265767      0.006249     579.0    45.227347       100.0
# CT       42979  12054.850002      0.008516     239.0    67.035277         2.0
# HI         653    461.199882      0.000768       1.0     0.706279         0.0
# OK        6692   1691.192581      0.012075     119.0    30.073508         5.0
# SC       12415   2411.281730      0.032592     267.0    51.857609         1.0
# UT       10202   3182.200141      0.024156     203.0    63.319607         0.0
# DC        8886  12590.878627      0.008000      29.0    41.091096         2.0
# KS        9965   3420.503248      0.011856      45.0    15.446327         5.0
# MO       14015   2283.529843      0.015905     291.0    47.413998        10.0
# VA       46239   5417.245278      0.020285     841.0    98.529451        15.0
# VT         988   1583.361245      0.003066       5.0     8.012962         0.0
# IA       20019   6345.025625      0.011762     320.0   101.424057         6.0
# LA       40746   8764.853852      0.009606     405.0    87.119369        34.0
# AK         486    664.347374      0.037648      20.0    27.339398         0.0
# AR        7818   2590.607474      0.030209     375.0   124.261679         3.0
# DE        9685   9945.941727      0.009666      80.0    82.155430         5.0
# ID        2933   1641.163262      0.006422      94.0    52.597800         1.0
# ME        2377   1768.322259      0.014583      28.0    20.830048         5.0
# MI       57731   5780.697571      0.004932     199.0    19.926189        37.0
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# (0.06, 0.12]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     46
# (0.06, 0.12]     4
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    13
# (50, 75]        10
# (75, 100]        9
# (40, 50]         6
# (0, 10]          5
# (20, 30]         4
# (10, 20]         4
# (30, 40]         1
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    14
# (50, 75]        10
# (75, 100]        6
# (30, 40]         6
# (40, 50]         4
# (10, 20]         4
# (0, 10]          4
# (20, 30]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (1, 2]       9
# (6, 8]       8
# (4, 6]       8
# (0, 1]       8
# (2, 3]       7
# (10, 500]    4
# (3, 4]       2
# (8, 10]      0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 4, 27)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 4, 18)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
m = states.deaths_1m_multi(d, 6)

# %%
m.loc[:, states.INTEREST].to_csv('~/Desktop/states.csv')

# %%
m['WI']
# Out:
# 04-28-2020    1.946494
# 05-05-2020    1.087747
# 05-12-2020    1.144997
# 05-19-2020    0.801498
# 05-26-2020    0.572498
# 06-02-2020    1.087747
# Name: WI, dtype: float64

# %%
m['deaths_1m'].mean()
# Out:
# 4.508771929824562

# %%
c = counties.deaths_1m(d)

# %%
c['deaths_1m'].value_counts().sort_index()
# Out:
# 0.0     20
# 1.0     21
# 2.0     15
# 3.0      4
# 4.0      3
# 5.0      3
# 6.0      1
# 10.0     3
# 11.0     1
# 12.0     2
# 13.0     1
# 14.0     3
# 16.0     2
# 17.0     1
# 18.0     1
# 19.0     3
# 20.0     1
# 21.0     2
# 22.0     1
# 23.0     1
# 24.0     1
# 26.0     3
# 27.0     1
# 34.0     1
# 40.0     1
# Name: deaths_1m, dtype: int64

# %%
a cd.counties_in_state('MA')

# %%
importlib.reload(counties)
# Out:
# <module 'counties' from '/Users/dd/gitcode/covid-compute/counties.py'>
