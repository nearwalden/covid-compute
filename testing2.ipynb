# %%
# Testing new file format

# %%
import pandas as p

# %%
import inspect

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 6, 30)

# %% [markdown]
# d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Boulder, CO')

# %%
cd.plot_state ('FL')

# %%
cd.plot_state ('US')

# %%
a = states.analyze()

# %%
a
# Out:
#           conf       conf/1M  conf_pct_chg  day conf  day conf/1M  day deaths  \
# state
# WA       32824   4310.500489      0.013430     571.0    74.984639        12.0
# IL      143185  11299.480951      0.004893     724.0    57.134645        21.0
# AZ       79228  10884.885344      0.031294    4683.0   643.382618        47.0
# CA      231232   5852.163772      0.030580    7586.0   191.991223        99.0
# MA      108882  15667.595222      0.001498     114.0    16.404051       -41.0
# WI       28659   4922.168289      0.014051     601.0   103.221436         7.0
# TX      163060   5623.557360      0.036417    6354.0   219.134573        39.0
# OR        8656   2052.285384      0.023890     171.0    40.543068         3.0
# RI       16813  15870.888205      0.003091      49.0    46.254299         4.0
# FL      152434   7097.302663      0.050842    6093.0   283.689106        58.0
# NH        5782   4252.374218      0.003755      22.0    16.179909         4.0
# NY      393454  20225.294485      0.001886      51.0     2.621628       629.0
# GA       81291   7656.377635      0.029128    1874.0   176.502340        21.0
# NC       65327   6228.687718      0.023759    1591.0   151.695963        23.0
# NJ      171667  19327.102888      0.001167     395.0    44.471014        43.0
# NV       18456   5991.904306      0.046511     562.0   182.458291         3.0
# TN       43509   6367.319199      0.026449    1212.0   177.369989        12.0
# CO       32698   5677.982113      0.007596     204.0    35.424440         9.0
# IN       45594   6772.506955      0.007298     366.0    54.365433        16.0
# KY       15624   3497.122551      0.005918     277.0    62.000957         5.0
# MD       67559  11174.756190      0.006032     305.0    50.449246        15.0
# MN       36303   6437.122138      0.011753     442.0    78.373908         6.0
# NE       19177   9913.627322      0.007086     135.0    69.788793         5.0
# PA       91139   7119.128129      0.005692     672.0    52.491843        35.0
# CT       46514  13046.355034      0.001687     152.0    42.633314         2.0
# HI         917    647.657415      0.016038      17.0    12.006735         0.0
# OK       13757   3476.649184      0.020706     582.0   147.082200         2.0
# SC       36399   7069.532314      0.041487    1755.0   340.861815        19.0
# UT       22217   6929.909874      0.024806     553.0   172.491343         4.0
# DC       10327  14632.681024      0.003713      35.0    49.592702         0.0
# KS       14370   4932.527012      0.021517     161.0    55.263525         0.0
# MO       21001   3421.791669      0.006130     176.0    28.676507         1.0
# VA       62787   7355.967458      0.007661     598.0    70.060180        23.0
# VT        1208   1935.931563      0.003329       0.0     0.000000         0.0
# IA       29074   9215.009493      0.013659     229.0    72.581591         5.0
# LA       58095  12496.789490      0.020906    1014.0   218.121087        22.0
# AK         937   1280.850802      0.028971      36.0    49.210917         0.0
# AR       20777   6884.759719      0.024230     520.0   172.309528         5.0
# DE       11474  11783.142527      0.012767      98.0   100.640402         2.0
# ID        6117   3422.773840      0.040398     365.0   204.236137         1.0
# ME        3253   2420.005178      0.010253      34.0    25.293629         0.0
# MI       70728   7082.108015      0.003896     505.0    50.566459        32.0
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# (0.06, 0.12]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     46
# (0.06, 0.12]     4
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    13
# (50, 75]        10
# (75, 100]        9
# (40, 50]         6
# (0, 10]          5
# (20, 30]         4
# (10, 20]         4
# (30, 40]         1
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    14
# (50, 75]        10
# (75, 100]        6
# (30, 40]         6
# (40, 50]         4
# (10, 20]         4
# (0, 10]          4
# (20, 30]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (1, 2]       9
# (6, 8]       8
# (4, 6]       8
# (0, 1]       8
# (2, 3]       7
# (10, 500]    4
# (3, 4]       2
# (8, 10]      0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 4, 27)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 4, 18)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
m = states.deaths_1m_multi(d, 6)

# %%
m.loc[:, states.INTEREST].to_csv('~/Desktop/states.csv')

# %%
m['CO']
# Out:
# 05-26-2020    1.447077
# 06-02-2020    1.794375
# 06-09-2020    1.504960
# 06-16-2020    1.157661
# 06-23-2020    1.041895
# 06-30-2020    0.926129
# Name: CO, dtype: float64

# %%
m['deaths_1m'].mean()
# Out:
# 4.508771929824562

# %%
c = counties.deaths_1m(d)

# %%
c['deaths_1m'].value_counts().sort_index()
# Out:
# 0.0     20
# 1.0     21
# 2.0     15
# 3.0      4
# 4.0      3
# 5.0      3
# 6.0      1
# 10.0     3
# 11.0     1
# 12.0     2
# 13.0     1
# 14.0     3
# 16.0     2
# 17.0     1
# 18.0     1
# 19.0     3
# 20.0     1
# 21.0     2
# 22.0     1
# 23.0     1
# 24.0     1
# 26.0     3
# 27.0     1
# 34.0     1
# 40.0     1
# Name: deaths_1m, dtype: int64

# %%
a cd.counties_in_state('MA')

# %%
importlib.reload(counties)
# Out:
# <module 'counties' from '/Users/dd/gitcode/covid-compute/counties.py'>
