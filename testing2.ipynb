# %%
# Testing new file format

# %%
import pandas as p

# %%
import inspect

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 7, 7)

# %%
covid.add_day("~/gitcode/", d)

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Los Angeles, CA')

# %%
cd.plot_state ('TX')

# %%
cd.plot_state ('US')

# %%
a = states.analyze()

# %%
a
# Out:
#           conf       conf/1M  conf_pct_chg  day conf  day conf/1M  day deaths  \
# state
# WA       37420   4914.054603      0.024375     435.0    57.124900        15.0
# IL      149574  11803.670522      0.004264    1709.0   134.866173       247.0
# AZ      105094  14438.533604      0.035780    3639.0   499.950747        98.0
# CA      284012   7187.952953      0.035305   12977.0   328.430015       132.0
# MA      110338  15877.106607      0.001360     201.0    28.922932        15.0
# WI       32556   5591.476005      0.016068     495.0    85.015992         9.0
# TX      216026   7450.230603      0.034702   10384.0   358.119831       101.0
# OR       10605   2514.381527      0.023170     210.0    49.789733         5.0
# RI       17154  16192.780365      0.000000     163.0   153.866340         9.0
# FL      213794   9954.214450      0.042295    7347.0   342.075145        63.0
# NH        5932   4362.691778      0.003570      18.0    13.238107         2.0
# NY      398237  20471.162066      0.001324     588.0    30.225829        24.0
# GA      100470   9462.748164      0.019875    3406.0   320.793473        21.0
# NC       76290   7273.969202      0.021436    1515.0   144.449644        14.0
# NJ      173878  19576.027984      0.001669     267.0    30.060154        52.0
# NV       23785   7722.011483      0.030488     876.0   284.401180        11.0
# TN       53514   7831.499681      0.018772    1475.0   215.858692        13.0
# CO       34647   6016.424438      0.005759     407.0    70.675232         5.0
# IN       48626   7222.878519      0.011457     102.0    15.151022        19.0
# KY       17519   3921.280720      0.023693     367.0    82.145672         9.0
# MD       70396  11644.016885      0.004051     492.0    81.380424        20.0
# MN       39133   6938.927930      0.012481     564.0   100.006525         3.0
# NE       20201  10442.988242      0.005508     155.0    80.127874        -1.0
# PA       95898   7490.867239      0.006252     798.0    62.334064        33.0
# CT       47033  13191.925363      0.002772      57.0    15.987493         0.0
# HI        1071    756.424310      0.015433      41.0    28.957420         0.0
# OK       17220   4351.813546      0.022570     858.0   216.832522         5.0
# SC       47352   9196.859643      0.033929     972.0   188.785005        19.0
# UT       26033   8120.193714      0.018713     564.0   175.922454         4.0
# DC       10569  14975.579136      0.003249      54.0    76.514455         0.0
# KS       16860   5787.223760      0.022661     222.0    76.201879         4.0
# MO       24918   4060.006895      0.013233     707.0   115.194834        16.0
# VA       66740   7819.091024      0.007599     638.0    74.746480        28.0
# VT        1254   2009.650811      0.005243       3.0     4.807777         0.0
# IA       32153  10190.899093      0.011164     395.0   125.195321         9.0
# LA       68263  14684.023426      0.023743    1936.0   416.452095        23.0
# AK        1180   1613.024489      0.024541      18.0    24.605458         1.0
# AR       24512   8122.406037      0.022251     259.0    85.823399         9.0
# DE       12414  12748.468828      0.012304     121.0   124.260088         2.0
# ID        8539   4778.006510      0.045253     487.0   272.501367         0.0
# ME        3440   2559.120139      0.003821      17.0    12.646815         1.0
# MI       73900   7399.725459      0.004715     633.0    63.383305        30.0
# MS       32214  10824.054844      0.009461     957.0   321.556481        44.0
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# (0.06, 0.12]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     46
# (0.06, 0.12]     4
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    13
# (50, 75]        10
# (75, 100]        9
# (40, 50]         6
# (0, 10]          5
# (20, 30]         4
# (10, 20]         4
# (30, 40]         1
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    14
# (50, 75]        10
# (75, 100]        6
# (30, 40]         6
# (40, 50]         4
# (10, 20]         4
# (0, 10]          4
# (20, 30]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (1, 2]       9
# (6, 8]       8
# (4, 6]       8
# (0, 1]       8
# (2, 3]       7
# (10, 500]    4
# (3, 4]       2
# (8, 10]      0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 4, 27)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 4, 18)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
m = states.deaths_1m_multi(d, 6)

# %%
m.loc[:, states.INTEREST].to_csv('~/Desktop/states.csv')

# %%
m['FL']
# Out:
# 06-02-2020    1.288156
# 06-09-2020    1.195036
# 06-16-2020    1.055356
# 06-23-2020    1.458875
# 06-30-2020    1.784794
# 07-07-2020    2.157273
# Name: FL, dtype: float64

# %%
m['deaths_1m'].mean()
# Out:
# 4.508771929824562

# %%
c = counties.deaths_1m(d)

# %%
c['deaths_1m'].value_counts().sort_index()
# Out:
# 0.0     20
# 1.0     21
# 2.0     15
# 3.0      4
# 4.0      3
# 5.0      3
# 6.0      1
# 10.0     3
# 11.0     1
# 12.0     2
# 13.0     1
# 14.0     3
# 16.0     2
# 17.0     1
# 18.0     1
# 19.0     3
# 20.0     1
# 21.0     2
# 22.0     1
# 23.0     1
# 24.0     1
# 26.0     3
# 27.0     1
# 34.0     1
# 40.0     1
# Name: deaths_1m, dtype: int64

# %%
a cd.counties_in_state('MA')

# %%
importlib.reload(counties)
# Out:
# <module 'counties' from '/Users/dd/gitcode/covid-compute/counties.py'>
