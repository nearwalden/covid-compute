# %%
# Testing new file format

# %%
import pandas as p

# %%
import datetime

# %%
a = p.read_csv('~/gitcode/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-14-2020.csv')

# %%
a.to_json()
# Out:
# '{"Province\\/State":{"0":"Hubei","1":null,"2":null,"3":null,"4":null,"5":null,"6":"France","7":null,"8":"Guangdong","9":"Henan","10":"Zhejiang","11":"United Kingdom","12":null,"13":"Hunan","14":"Anhui","15":null,"16":null,"17":"Jiangxi","18":"Denmark","19":null,"20":"Shandong","21":"Diamond Princess","22":null,"23":null,"24":"Jiangsu","25":"Chongqing","26":"Washington","27":"Sichuan","28":"New York","29":"Heilongjiang","30":"Beijing","31":"Shanghai","32":"California","33":null,"34":"Hebei","35":"Fujian","36":"Guangxi","37":"Shaanxi","38":null,"39":null,"40":null,"41":null,"42":null,"43":null,"44":null,"45":null,"46":"Yunnan","47":null,"48":"Hainan","49":null,"50":null,"51":"Guizhou","52":"Hong Kong","53":"Massachusetts","54":"Tianjin","55":"Shanxi","56":"Gansu","57":null,"58":"Liaoning","59":null,"60":null,"61":"New South Wales","62":null,"63":null,"64":null,"65":null,"66":null,"67":null,"68":null,"69":"Colorado","70":null,"71":"Jilin","72":null,"73":null,"74":null,"75":null,"76":"O
# ...
