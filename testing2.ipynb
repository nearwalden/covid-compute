# %%
# Testing new file format

# %%
import pandas as p

# %%
import inspect

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 5, 19)

# %%
d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Los Angeles, CA')

# %%
cd.plot_state ('CA')

# %%
cd.plot_state ('MN')

# %%
a = states.analyze()

# %%
a
# Out:
#           conf       conf/1M  conf_pct_chg  day conf  day conf/1M  day deaths  \
# state
# WA       18433   2420.651216      0.014394     145.0    19.041633         2.0
# IL       94191   7433.106891      0.025381    1734.0   136.839054        48.0
# AZ       13945   1915.859622      0.038398     279.0    38.330931         1.0
# CA       80166   2028.891161      0.025415    1441.0    36.469727        32.0
# MA       86010  12376.424616      0.016601    1077.0   154.975111        92.0
# WI       12543   2154.253702      0.039662     356.0    61.142814         0.0
# TX       48396   1669.064651      0.032880     944.0    32.556348        25.0
# OR        3623    858.991445      0.018936      11.0     2.608034         0.0
# RI       12674  11963.815923      0.017245     240.0   226.551667        10.0
# FL       45588   2122.569990      0.018362     777.0    36.176996         9.0
# NH        3596   2644.679641      0.025411      40.0    29.418016         1.0
# NY      350121  17997.784570      0.007523    1889.0    97.103045       183.0
# GA       37579   3539.371088      0.017032     367.0    34.565826        12.0
# NC       18673   1780.401454      0.033677     543.0    51.773041        10.0
# NJ      146504  16494.130389      0.008322    1415.0   159.307558       102.0
# NV        6949   2256.054563      0.023545     136.0    44.153608         3.0
# TN       17359   2540.400698      0.016748      96.0    14.049108         3.0
# CO       21938   3809.516533      0.018897     305.0    52.963011        23.0
# IN       27778   4126.128398      0.023277     498.0    73.972638        10.0
# KY        7688   1720.806335      0.031545       0.0     0.000000         0.0
# MD       38804   6418.467402      0.028358     836.0   138.280557        35.0
# MN       15668   2778.195457      0.055556     699.0   123.944257        22.0
# NE       10177   5261.041104      0.050636     -43.0   -22.229023         0.0
# PA       65700   5132.015033      0.016347     515.0    40.228124        15.0
# CT       37419  10495.368255      0.017318     716.0   200.825347        69.0
# HI         640    452.018262      0.001569       1.0     0.706279         0.0
# OK        5310   1341.935536      0.027236      73.0    18.448455         0.0
# SC        8816   1712.272230      0.028417     155.0    30.104605         5.0
# UT        7238   2257.671498      0.023361     170.0    53.026272         2.0
# DC        7123  10092.823369      0.022464      81.0   114.771682         8.0
# KS        7953   2729.880816      0.015106      14.0     4.805524         0.0
# MO       11108   1809.878666      0.017081     149.0    24.277271         6.0
# VA       30388   3560.181871      0.033073     705.0    82.596032         7.0
# VT         940   1506.436812      0.001072       6.0     9.615554         1.0
# IA       14651   4643.637067      0.023604     323.0   102.374908         5.0
# LA       34432   7406.652134      0.009333     315.0    67.759509        12.0
# AK         388    530.384324      0.006527       0.0     0.000000         0.0
# AR        4759   1576.963542      0.023992     181.0    59.976970         0.0
# DE        7670   7876.651838      0.022183     123.0   126.313973         4.0
# ID        2419   1353.554017      0.014462       0.0     0.000000         0.0
# ME        1687   1255.010370      0.026177      39.0    29.013281         0.0
# MI       51142   5120.930439      0.009595     604.0    60.479488        10.0
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     46
# (0.06, 0.12]     2
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (50, 75]        11
# (100, 10000]    10
# (30, 40]         8
# (10, 20]         6
# (20, 30]         4
# (0, 10]          4
# (40, 50]         3
# (75, 100]        2
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    14
# (50, 75]        10
# (75, 100]        6
# (30, 40]         6
# (40, 50]         4
# (10, 20]         4
# (0, 10]          4
# (20, 30]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 1]       15
# (1, 2]       10
# (10, 500]     4
# (3, 4]        4
# (2, 3]        3
# (8, 10]       2
# (4, 6]        2
# (6, 8]        0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 4, 27)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 4, 18)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
m = states.deaths_1m_multi(d, 6)

# %%
m.loc[:, states.INTEREST].to_csv('~/Desktop/states.csv')

# %%
m['CO']
# Out:
# 04-12-2020    5.556775
# 04-19-2020    3.762400
# 04-26-2020    7.872098
# 05-03-2020    3.762400
# 05-10-2020    1.562843
# 05-17-2020    7.466916
# Name: CO, dtype: float64

# %%
m['deaths_1m'].mean()
# Out:
# 4.508771929824562

# %%
c = counties.deaths_1m(d)

# %%
c['deaths_1m'].value_counts().sort_index()
# Out:
# 0.0     20
# 1.0     21
# 2.0     15
# 3.0      4
# 4.0      3
# 5.0      3
# 6.0      1
# 10.0     3
# 11.0     1
# 12.0     2
# 13.0     1
# 14.0     3
# 16.0     2
# 17.0     1
# 18.0     1
# 19.0     3
# 20.0     1
# 21.0     2
# 22.0     1
# 23.0     1
# 24.0     1
# 26.0     3
# 27.0     1
# 34.0     1
# 40.0     1
# Name: deaths_1m, dtype: int64

# %%
a cd.counties_in_state('MA')

# %%
importlib.reload(counties)
# Out:
# <module 'counties' from '/Users/dd/gitcode/covid-compute/counties.py'>
