# %%
# Testing new file format

# %%
import pandas as p

# %%
import inspect

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 6, 24)

# %% [markdown]
# d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
cd = covid.CovidData()

# %%
cd.plot_county('Los Angeles, CA')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
cd.plot_state ('FL')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
cd.plot_state ('US')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
a = states.analyze()

# %%
a
# Out:
#           conf       conf/1M  day conf  day conf/1M  deaths    deaths/1M  \
# state
# WA       28680   3766.303742     455.0    59.751332    1270   166.778443
# IL      136762  10792.608260     658.0    51.926239    6647   524.549708
# AZ       52591   7225.311823    2464.0   338.521198    1349   185.334861
# CA      178546   4518.753602    3333.0    84.353644    5515   139.577062
# MA      107061  15405.562096     125.0    17.986898    7857  1130.584446
# WI       24819   4262.650294     280.0    48.089854     744   127.781612
# TX      112944   3895.173939    3363.0   115.981991    2191    75.562457
# OR        6572   1558.181556       0.0     0.000000     188    44.573666
# RI       16337  15421.560733       0.0     0.000000     894   843.904958
# FL       97291   4529.853401    3494.0   162.680081    3161   147.175654
# NH        5544   4077.337022      26.0    19.121710     339   249.317686
# NY      387936  19941.644617     664.0    34.132568   31125  1599.964140
# GA       64701   6093.851587     892.0    84.012853    2643   248.930461
# NC       52801   5034.379969    1411.0   134.533629    1223   116.608524
# NJ      169142  19042.826150     308.0    34.676133   12939  1456.735332
# NV       13240   4298.483583     264.0    85.709945     487   158.108875
# TN       35102   5136.997829     656.0    96.002238     526    76.977405
# CO       30524   5300.468714     191.0    33.167001    1647   286.000261
# IN       42423   6301.488410     362.0    53.771275    2540   377.290162
# KY       13750   3077.664816     120.0    26.859620     526   117.734669
# MD       64306  10636.686030     350.0    57.892578    3066   507.138982
# MN       32920   5837.260304     453.0    80.324390    1412   250.370946
# NE       17812   9207.985079     105.0    54.280173     244   126.136782
# PA       85935   6712.628795     345.0    26.948937    6423   501.718913
# CT       45755  12833.468947      40.0    11.219293    4260  1194.854720
# HI         814    574.910726      25.0    17.656963      17    12.006735
# OK       10516   2657.588342     478.0   120.799470     369    93.253147
# SC       24661   4789.739729     905.0   175.772047     653   126.827787
# UT       17462   5446.733862     394.0   122.896183     158    49.283241
# DC       10020  14197.682179      36.0    51.009637     533   755.226008
# KS       12136   4165.702701      39.0    13.386817     257    88.215688
# MO       18459   3007.611658     403.0    65.662685     965   157.231987
# VA       57994   6794.431598     551.0    64.553778    1611   188.740720
# VT        1159   1857.404538      12.0    19.231108      56    89.745172
# IA       25963   8228.977487     467.0   148.015733     686   217.427823
# LA       49778  10707.723336     393.0    84.538054    3105   667.915163
# AK         752   1027.961369      11.0    15.036669      12    16.403639
# AR       15561   5156.362612     419.0   138.841715     225    74.557007
# DE       10775  11065.309459      94.0    96.532630     435   446.720150
# ID        4006   2241.561550       2.0     1.119102      89    49.800044
# ME        2957   2199.801817      19.0    14.134675     102    75.880888
# MI       67711   6780.010968     166.0    16.621846    6090   609.801462
# MS       20641   6935.472653       0.0     0.000000     938   315.172392
# MT         717    670.859617      19.0    17.777312      20    18.712960
# ND        3288   4314.609572      37.0    48.552480      77   101.041648
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# (0.06, 0.12]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.0, 0.06]     46
# (0.06, 0.12]     4
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# (0.12, 0.24]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    13
# (50, 75]        10
# (75, 100]        9
# (40, 50]         6
# (0, 10]          5
# (20, 30]         4
# (10, 20]         4
# (30, 40]         1
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    14
# (50, 75]        10
# (75, 100]        6
# (30, 40]         6
# (40, 50]         4
# (10, 20]         4
# (0, 10]          4
# (20, 30]         3
# Name: new_cases_1m, dtype: int64

# %%
d = d + datetime.timedelta(days=-7)

# %%
d
# Out:
# datetime.date(2020, 4, 19)

# %%
states.deaths_1m_bins(d)
# Out:
# (1, 2]       9
# (6, 8]       8
# (4, 6]       8
# (0, 1]       8
# (2, 3]       7
# (10, 500]    4
# (3, 4]       2
# (8, 10]      0
# Name: deaths_1m, dtype: int64

# %%
states.deaths_1m_bins(d)
# Out:
# (0, 2]       18
# (2, 4]       12
# (6, 8]        5
# (25, 500]     4
# (15, 20]      2
# (4, 6]        2
# (10, 15]      1
# (20, 25]      0
# (8, 10]       0
# Name: deaths_1m, dtype: int64

# %%
d2 = datetime.date(2020, 4, 27)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 4, 18)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
m = states.deaths_1m_multi(d, 6)

# %%
m.loc[:, states.INTEREST].to_csv('~/Desktop/states.csv')

# %%
m['FL']
# Out:
# 05-20-2020    1.908953
# 05-27-2020    1.272636
# 06-03-2020    1.784794
# 06-10-2020    1.567515
# 06-17-2020    1.350235
# 06-24-2020    1.862394
# Name: FL, dtype: float64

# %%
m['deaths_1m'].mean()
# Out:
# 4.508771929824562

# %%
c = counties.deaths_1m(d)

# %%
c['deaths_1m'].value_counts().sort_index()
# Out:
# 0.0     20
# 1.0     21
# 2.0     15
# 3.0      4
# 4.0      3
# 5.0      3
# 6.0      1
# 10.0     3
# 11.0     1
# 12.0     2
# 13.0     1
# 14.0     3
# 16.0     2
# 17.0     1
# 18.0     1
# 19.0     3
# 20.0     1
# 21.0     2
# 22.0     1
# 23.0     1
# 24.0     1
# 26.0     3
# 27.0     1
# 34.0     1
# 40.0     1
# Name: deaths_1m, dtype: int64

# %%
a cd.counties_in_state('MA')

# %%
importlib.reload(counties)
# Out:
# <module 'counties' from '/Users/dd/gitcode/covid-compute/counties.py'>
