# %%
# Testing new file format

# %%
import pandas as p

# %%
import datetime

# %%
import covid

# %%
import state_fixes

# %%
import states

# %%
import counties

# %%
import importlib

# %%
importlib.reload(states)
# Out:
# <module 'states' from '/Users/dd/gitcode/covid-compute/states.py'>

# %%
d = datetime.date(2020, 4, 14)

# %%
d = d + datetime.timedelta(days=1)

# %%
covid.add_day("~/gitcode/", d)

# %%
b = p.read_csv('~/gitcode/covid-compute/data/state_confirmed.csv')

# %%
cd = covid.CovidData()

# %%
cd.plot_county_new_deaths(['Dane, WI'])

# %%
cd.plot_state_new_cases(['FL'])

# %%
a = states.analyze()

# %%
a.to_csv('results/counties-2020040.csv')

# %%
a
# Out:
#          conf       conf/1M  conf_days_peak  conf_pct_chg  conf_pct_chg_prev  \
# state
# WA      10799   1418.142054              12      0.008936           0.023951
# IL      23248   1834.621875               4      0.055891           0.079731
# AZ       3809    523.306511               9      0.037045           0.067105
# CA      25356    641.725473               9      0.054691           0.039909
# MA      28164   4052.663910               2      0.051458           0.102156
# WI       3555    610.569394               9      0.031544           0.043550
# TX      15006    517.521782               5      0.047466           0.063028
# OR       1633    387.174449               9      0.034131           0.075425
# RI       3251   3068.831116               3      0.109944           0.247344
# FL      21628   1006.996221               1      2.179612           0.065343
# NH        922    678.085270              11     -0.001840           0.065152
# NY     203020  10436.135574               6      0.036336           0.047291
# GA      14578   1373.026204               7      0.082081           0.041391
# NC       5113    487.505630               3      0.057803           0.073859
# NJ      68824   7748.539493              11      0.054927           0.064441
# NV       3134   1017.480933              16      0.051231           0.021123
# TN       5827    852.751591              13      0.028600           0.061270
# CO       7946   1379.816682               2      0.042854           0.086028
# IN       8527   1266.595754               4      0.037231           0.071376
# KY       2048    458.404185               4      0.021442           0.079740
# MD       6999   1157.686149               6     -0.065160           0.086603
# MN       1695    300.551525               2      0.022825           0.102032
# NE        897    463.707760               2      0.065521           0.116202
# PA      25465   1989.144031              10      0.053658           0.069657
# CT      13989   3923.667295               5      0.078639           0.068925
# HI        511    360.908331              11      0.011954           0.062577
# OK       2184    551.937328              10      0.052918           0.047926
# SC       3553    690.075230               5      0.034580           0.040449
# UT       2417    753.908816               4      0.024453           0.046476
# DC       2058   2916.050891               6      0.047676           0.062820
# KS       1441    494.625708               3      0.035458           0.097784
# MO       4746    773.288094               4      0.054394           0.046668
# VA       6182    724.267616               3      0.082688           0.082386
# VT        752   1205.149450              10      0.017117           0.034816
# IA       1899    601.888389               0      0.094016           0.069445
# LA      21518   4628.727365              12      0.022164           0.034278
# AK        285    389.586423               7      0.023632           0.051541
# AR       1498    496.383985               1      0.081987           0.045511
# DE       1926   1977.891974               6      0.088705           0.107050
# ID       1464    819.182753              12      0.020076           0.019449
# ME        735    546.788751              12      0.077847           0.039396
# MI      27001   2703.653412              11      0.055331           0.039634
# MS       3087   1037.246455               5      0.053590           0.061340
# MT        399    373.323553              12      0.015389           0.029701
# ND        341    447.470153              17      0.052443           0.052576
# NM       1345    641.444772               4      0.039712           0.075203
# OH       7285    623.230189              10      0.050311           0.059963
# SD        988   1116.814501               1      0.163645           0.167022
# PA                0.155353
# CT                0.112068
# HI                0.229167
# OK                0.044729
# SC                0.068056
# UT                0.029412
# DC                0.150336
# KS                0.163853
# MO                0.094479
# VA                0.079498
# VT                0.060833
# IA                0.151328
# LA                0.054867
# AK                0.071429
# AR                0.135238
# DE                0.045928
# ID                0.060833
# ME                0.058824
# MI                0.076641
# MS                0.083202
# MT                0.000000
# ND                0.083333
# NM                0.243034
# OH                0.046778
# SD                0.000000
# WV                0.100000
# WY                     NaN
# AL                0.080435
# PR                0.062271
# VI                0.000000
# GU                0.125000
# AS                     NaN
# MP                0.000000
# US                0.088626

# %%
states.pct_change_bins_conf(d)
# Out:
# (0.0, 0.06]     40
# (0.06, 0.12]     9
# (1.4, 20.0]      1
# (0.12, 0.24]     1
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins(d)
# Out:
# (0.0, 0.06]     30
# (0.06, 0.12]    20
# (0.12, 0.24]     2
# (1.4, 20.0]      1
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# (0.24, 0.35]     0
# Name: pct_change_2day, dtype: int64

# %%
states.cases_1m_bins(d)
# Out:
# (100, 10000]    11
# (20, 30]        10
# (10, 20]         9
# (40, 50]         5
# (30, 40]         5
# (5, 10]          3
# (75, 100]        2
# (50, 75]         2
# (0, 5]           2
# Name: new_cases_1m, dtype: int64

# %%
states.cases_1m_bins(d - datetime.timedelta(days=7))
# Out:
# (0.06, 0.12]    29
# (0.12, 0.24]    24
# (0.24, 0.35]     1
# (0.0, 0.06]      1
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# Name: pct_change_2day, dtype: int64

# %%
d1 = datetime.date(2020, 3, 29)

# %%
states.pct_change_bins_deaths(d1)
# Out:
# (0.12, 0.24]    16
# (0.35, 0.7]     14
# (0.24, 0.35]     7
# (0.7, 1.4]       3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# (1.4, 20.0]      0
# Name: pct_change_2day, dtype: int64

# %%
d2 = datetime.date(2020, 3, 22)

# %%
states.pct_change_bins(d2)
# Out:
# (0.24, 0.35]    21
# (0.35, 0.7]     20
# (0.12, 0.24]    14
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.06, 0.12]     0
# (0.0, 0.06]      0
# Name: pct_change_2day, dtype: int64

# %%
d3 = datetime.date(2020, 3, 15)

# %%
states.pct_change_bins(d3)
# Out:
# (0.35, 0.7]     14
# (0.24, 0.35]    10
# (0.12, 0.24]    10
# (0.7, 1.4]       8
# (1.4, 20.0]      3
# (0.06, 0.12]     3
# (0.0, 0.06]      1
# Name: pct_change_2day, dtype: int64

# %%
states.pct_change_bins_deaths(d)
# Out:
# (0.06, 0.12]    26
# (0.0, 0.06]     14
# (0.12, 0.24]    11
# (0.24, 0.35]     1
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# (0.35, 0.7]      0
# Name: pct_change_2day, dtype: int64

# %%
d45 = datetime.date(2020, 4, 5)

# %%
states.pct_change_bins_deaths(d45)
# Out:
# (0.12, 0.24]    26
# (0.06, 0.12]    12
# (0.24, 0.35]     7
# (0.0, 0.06]      4
# (0.35, 0.7]      1
# (1.4, 20.0]      0
# (0.7, 1.4]       0
# Name: pct_change_2day, dtype: int64

# %%
cd.plot_state_pct_change(['CO'])
