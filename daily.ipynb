# %%
import daily

# %%
import importlib

# %%
importlib.reload(daily)
# Out:
# <module 'daily' from '/Users/dd/gitcode/covid-compute/daily.py'>

# %%
daily.plot()

# %%
a
# Out:
#                 ca        fl        tx        az        co
# date
# 20200704  0.062086  0.175906  0.142618  0.242204  0.048865
# 20200703  0.073453  0.192936  0.198278  0.252708  0.045913
# 20200702  0.089163  0.195045  0.146969  0.296451  0.054590
# 20200701  0.111906  0.185610  0.153344  0.282889  0.055952
# 20200630  0.060381  0.188919  0.139241  0.223666  0.047530
# ...            ...       ...       ...       ...       ...
# 20200308  1.000000  0.142857       NaN       NaN  0.000000
# 20200307  1.000000  0.100000  1.000000  0.153846  0.400000
# 20200306  1.000000  0.000000  1.000000  0.166667  0.068966
# 20200305       NaN  0.500000       NaN  0.000000       NaN
# 20200304       NaN       NaN       NaN       NaN       NaN
#
# [123 rows x 5 columns]
